# %%
(lambda x: x * 2)(int(input('please enter a number')))
# Out:
# please enter a number7
# 14

# %%
(lambda name:'f{name} start with upper case s'if name.startswith('s') else f'{name} does not start with upper case s')(input('provide a name :'))
# Out:
# provide a name :simeon
# 'f{name} start with upper case s'

# %%
(lambda password: True if password[-1]=='0'or password[-1]=='1'or password[-1]=='2'or password[-1]=='3'or password[-1]=='4'or password[-1]=='5'or password[-1]=='6'or password[-1]=='7'or password[-1]=='8'or password[-1]=='9'
# Out:
# provide a passowrd:9
# '9 ends with a digit'

# %%
import math as m

# %%
print(dir(m))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc']

# %%
from math import acosh
(lambda num: acosh(num))(int(input('provide a number:')))
# Out:
# provide a number:58
# 4.753515866530499

# %%
dog = ['bingo','rocky','bella','jack']
udog = list(map(lambda x: str.upper(x),dog))
print(udog)
# Out:
# ['BINGO', 'ROCKY', 'BELLA', 'JACK']

# %%
dog = ['bingo','rocky','bella','jack']
udog2 = list(filter(lambda x: x.startswith('b'),dog))
print(udog2)
# Out:
# ['bingo', 'bella']

# %%
import random

# %%
nums =[]
counter = 1
while counter <=100:
    num =random.randint(25,40)
    nums.append(num)
    counter +=1

# %%
print(nums)
# Out:
# [26, 30, 25, 26, 35, 39, 36, 27, 34, 30, 37, 30, 37, 25, 39, 27, 26, 34, 39, 40, 28, 40, 39, 28, 37, 40, 40, 40, 33, 38, 38, 35, 35, 29, 27, 26, 38, 33, 38, 37, 35, 34, 32, 25, 26, 30, 34, 37, 33, 39, 26, 27, 25, 25, 36, 36, 37, 27, 28, 35, 27, 36, 29, 38, 25, 28, 30, 28, 33, 31, 29, 25, 25, 39, 38, 33, 38, 29, 32, 32, 35, 35, 40, 35, 38, 30, 30, 32, 31, 26, 37, 37, 29, 29, 39, 30, 36, 37, 32, 26]

# %%
from math import log10
lognum = list(map(lambda n: log10(n),numbers))
print(lognum)
# Out:
# [1.5314789170422551, 1.591064607026499, 1.5563025007672873, 1.5314789170422551, 1.3979400086720377, 1.5185139398778875, 1.505149978319906, 1.4471580313422192, 1.5440680443502757, 1.4913616938342726, 1.414973347970818, 1.414973347970818, 1.4313637641589874, 1.591064607026499, 1.5440680443502757, 1.505149978319906, 1.505149978319906, 1.6020599913279623, 1.5185139398778875, 1.5563025007672873, 1.4471580313422192, 1.505149978319906, 1.5314789170422551, 1.3979400086720377, 1.6020599913279623, 1.505149978319906, 1.4313637641589874, 1.4771212547196624, 1.505149978319906, 1.462397997898956, 1.4771212547196624, 1.5314789170422551, 1.5797835966168101, 1.5314789170422551, 1.6020599913279623, 1.3979400086720377, 1.414973347970818, 1.4913616938342726, 1.5440680443502757, 1.3979400086720377, 1.505149978319906, 1.4471580313422192, 1.5797835966168101, 1.5563025007672873, 1.4313637641589874, 1.5440680443502757, 1.5440680443502757, 1.4913616938342726, 1.3979400086720377, 1.5185139398778875, 1.56820172
# ...

# %%
even = list(filter(lambda x:  x%2 ==0, numbers))
odd = list(filter(lambda x: x%2 ==1,numbers))
print(even)
print('\n')
print(odd)
# Out:
# [34, 36, 34, 32, 28, 26, 26, 32, 32, 40, 36, 28, 32, 34, 40, 32, 30, 32, 30, 34, 38, 34, 40, 26, 32, 28, 38, 36, 30, 30, 26, 34, 36, 26, 34, 36, 30, 30, 40, 28, 38, 40, 40, 32, 30, 36, 32, 36, 38, 28, 38, 34, 28, 26, 38, 26]
#
#
# [39, 25, 33, 35, 31, 27, 39, 35, 33, 25, 27, 29, 25, 31, 35, 25, 27, 35, 35, 31, 25, 33, 37, 27, 31, 29, 33, 31, 35, 37, 37, 29, 33, 29, 31, 29, 25, 31, 29, 31, 33, 31, 27, 27]

# %% [markdown]
# # assignment
# declare the following variable JUNIOR and assign JNR,INTERMIDEATE and assign and SENIOR and assign SRN
# generate 5000 numbers between 1 and 2000 and join it with all the above variable one after the other in just one program
# and append the list to list called staff list
# filter that list by getting out only the junior staff

# %%
import random

# %%
nums =[]
counter = 1
while counter <=5000:
    num = random.randint(1,2000)
    nums.append(num)
    counter +=1

# %%
print(nums)
# Out:
# [1209, 1732, 186, 472, 682, 1947, 1819, 946, 128, 1218, 909, 1325, 874, 446, 834, 1517, 1715, 1039, 2, 1635, 571, 1009, 1790, 552, 32, 239, 483, 697, 1626, 132, 1325, 446, 508, 1071, 743, 1697, 1598, 65, 1309, 1555, 23, 1785, 1205, 628, 1409, 1026, 1220, 692, 1189, 1084, 1, 1221, 1853, 1792, 1605, 1610, 1561, 164, 618, 1862, 795, 1952, 405, 1129, 1985, 506, 1082, 1767, 527, 517, 749, 1945, 1528, 208, 84, 1114, 1648, 863, 239, 1826, 1742, 207, 718, 1716, 1981, 1265, 1232, 1080, 632, 1187, 541, 1699, 752, 1939, 929, 963, 28, 351, 1347, 508, 483, 682, 620, 273, 1494, 556, 1619, 605, 1042, 1109, 502, 1737, 1756, 468, 164, 1316, 1969, 296, 1807, 184, 730, 323, 991, 874, 1958, 830, 894, 946, 73, 1199, 947, 1794, 1913, 2000, 89, 1355, 1208, 1803, 1922, 174, 110, 448, 849, 1453, 947, 1773, 1553, 1941, 547, 200, 1222, 170, 1412, 167, 1729, 1885, 1867, 174, 611, 1058, 234, 1612, 659, 1934, 847, 664, 1558, 280, 1341, 763, 1293, 1607, 127, 1244, 408, 686, 1814, 58, 1766, 948, 786, 1267, 1922, 40
# ...

# %%
import random
junior = 'jnr'
intermidiate = 'itm'
senior = 'srn'
staffnumberlist = []
counter = 1
while counter <= 5000:
    n= random.randint(1,500)
    sn = str(n)
    staffnumberlist.append(junior + sn)
    staffnumberlist.append(intermidate + sn)
    staffnumberlist.append(senior + sn)
    counter += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-49ae1520978d> in <module>
#       9     sn = str(n)
#      10     staffnumberlist.append(junior + sn)
# ---> 11     staffnumberlist.append(intermidate + sn)
#      12     staffnumberlist.append(senior + sn)
#      13     counter += 1
#
# NameError: name 'intermidate' is not defined
